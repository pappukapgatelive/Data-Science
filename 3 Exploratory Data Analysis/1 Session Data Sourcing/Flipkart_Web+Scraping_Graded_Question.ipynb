# %% [markdown]
# ## HTML Page Read and Upload

# %%
# Import useful libraries and classes.
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
#html page upload and read in web_page variable.
my_url=  "https://www.flipkart.com/search?p%5B%5D=facets.brand%255B%255D%3DSamsung&sid=tyy%2F4io&sort=recency_desc&wid=1.productCard.PMU_V2_1"
web_page= uReq(my_url)
page_html= web_page.read()

# %% [markdown]
# ## Parsing

# %%
#html parser. It is to beautify the HTML code.
page_soup= soup(page_html)
page_soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.8683fa.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
print(soup.prettify(containers[0]))
# Out:
# <div class="_1-2Iqu row">
#  <div class="col col-7-12">
#   <div class="_3wU53n">
#    Samsung GALAXY M51 (ELECTRIC BLUE, 128 GB)
#   </div>
#   <div class="niH0FQ">
#    <span class="_2_KrJI" id="productRating_LSTMOBFVVEJRYZ73YSFGYJJZ0_MOBFVVEJRYZ73YSF_">
#     <div class="hGSR34">
#      4.1
#      <img class="_2lQ_WZ" src="..."/>
#     </div>
#    </span>
#    <span class="_38sUEc">
#     <span>
#      <span>
#       19 Ratings
#      </span>
#      <span class="_1VpSqZ">
#       &amp;
#      </span>
#      <span>
#       0 Reviews
#      </span>
#     </span>
#    </span>
#   </div>
#   <div class="_3ULzGw">
#    <ul class="vFw0gD">
#     <li class="tVe95H">
#      6 GB RAM | 128 GB ROM
#     </li>
#     <li class="tVe95H">
#      17.02 cm (6.7 inch) Display
#     </li>
#     <li class="tVe95H">
#      64MP Rear Camera
#     </li>
#     <li class="tVe95H">
#      7000 mAh Battery
#     </li>
#     <li class="tVe95H">
#      ONE YEAR COMPANY WARRANTY
#     </li>
#    </ul>
# ...

# %% [markdown]
# ## Extraction of information

# %%
#read class attribute from web page in containers variable.
# Print the length of containers.
containers= page_soup.findAll("div", {"class": "_1-2Iqu row"})
print(len(containers))
# Out:
# 24

# %%
# Extract the model name of 6th phone in the list.
filename= "flicard.csv"
f= open(filename, "w")
headers= "Name, Rating \n"
f.write(headers) 

for container in containers:
    phone= container.findAll("div", {"class": "_3wU53n"})
    phone_name =  phone[0].text
    rating = container.findAll("div", {"class": "hGSR34"})
    phone_rating = rating[0].text
    print(phone_name + "," +phone_rating + "\n")
    f.write(phone_name + "," +phone_rating + "\n")
    
f.close()
# Out:
# Samsung GALAXY M51 (ELECTRIC BLUE, 128 GB),4.1
#
# Samsung GALAXY M51 (Celestial Black, 128 GB),4.1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-cbe54ea7068e> in <module>
#       9     phone_name =  phone[0].text
#      10     rating = container.findAll("div", {"class": "hGSR34"})
# ---> 11     phone_rating = rating[0].text
#      12     print(phone_name + "," +phone_rating + "\n")
#      13     f.write(phone_name + "," +phone_rating + "\n")
#
# IndexError: list index out of range

# %%
# how many elements does 'tVe95H' class contained in it?

# %%
# Read the camera specification of 8th phone in the list.
